# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

file_path=r'/spam_emails.xlsx'
df=pd.read_excel(file_path)

print("Dataset preview:")
print(df)

df["text"]=df["text"].str.replace(r'[^a-zA-z ]','',regex=True)
df["text"]=df["text"].str.replace('Subject','')
df["text"]=df["text"].str.lower()

print("Processed dataset:")
print(df)

messages=df['text']
labels=df['label']

spam_messages=messages[labels=='spam']
ham_messages=messages[labels=='not spam']

print("\nspam messages")
print(spam_messages)
print("\nham messages")
print(ham_messages)

spam_word_count={}
ham_word_count={}

for m in spam_messages:
    words = str(m).split()
    for word in words:
        if word in spam_word_count:
            spam_word_count[word] += 1
        else:
            spam_word_count[word] = 1

for m in ham_messages:
    words = str(m).split()
    for word in words:
        if word in ham_word_count:
            ham_word_count[word] += 1
        else:
            ham_word_count[word] = 1

print("\nspam words count")
print(spam_word_count)

print("\nham words count")
print(ham_word_count)

print("\nFROM THE GIVEN DATA SET WE CAN FIND THE FOLLOWING")

print("\npriori probability of spam mails")
priori_p_spam=len(spam_messages)/len(messages)
print(priori_p_spam)
print("\npriori probability of ham mails")
priori_p_ham=len(ham_messages)/len(messages)
print(priori_p_ham)

print("\nEnter the mail!")
mail=input()

words = mail.lower().split()
print(f"\nWords in the mail:{words}")

class_conditional_p_spam = 1
class_conditional_p_ham = 1

for word in words:
    p_word_given_spam = ((spam_word_count.get(word, 0) + 1) /
                         (spam_word_count.get(word, 0) + ham_word_count.get(word, 0) + 1))
    class_conditional_p_spam *= p_word_given_spam

    p_word_given_ham = ((ham_word_count.get(word, 0) + 1) /
                        (spam_word_count.get(word, 0) + ham_word_count.get(word, 0) + 1))
    class_conditional_p_ham *= p_word_given_ham

    k = spam_word_count.get(word, 0)
    g = ham_word_count.get(word, 0)
    print(f"\ncount of the word '{word}' in spam mails")
    print(k)
    print(f"count of the word '{word}' in ham mails")
    print(g)

    print(f"\nClass conditional probabilities of word:{word}")
    print(f"Probability(word/spam)={p_word_given_spam}")
    print(f"Probability(word/ham)={p_word_given_ham}")



posterior_p_spam_given_word = ((priori_p_spam*class_conditional_p_spam)/
                               (priori_p_spam*class_conditional_p_spam+priori_p_ham*class_conditional_p_ham))

posterior_p_ham_given_word = ((priori_p_ham * class_conditional_p_ham) /
                                   (priori_p_spam * class_conditional_p_spam + priori_p_ham * class_conditional_p_ham))

print("\nPosterior probability of this mail to be a spam is")
print(posterior_p_spam_given_word)
print("\nPosterior probability of this mail to be a ham is")
print(posterior_p_ham_given_word)

if posterior_p_spam_given_word > posterior_p_ham_given_word:
    print("\nHence the mail is a spam!")
else:
    print("\nHence the mail is not a spam!")
# Out:
# Dataset preview:
#                                                   text     label
# 0    Subject: naturally irresistible your corporate...      spam
# 1    Subject: the stock trading gunslinger  fanny i...      spam
# 2    Subject: unbelievable new homes made easy  im ...      spam
# 3    Subject: 4 color printing special  request add...      spam
# 4    Subject: do not have money , get software cds ...      spam
# ..                                                 ...       ...
# 495  Subject: re : invitation to speak at power 200...  not spam
# 496  Subject: re : aram ' s visit  jesus ,  i yalke...  not spam
# 497  Subject: - - - - - - - - - - - - - - - - - - -...  not spam
# 498  Subject: reschedule meeting for duffie report ...  not spam
# 499  Subject: re : enl - dailyupdate - txt  please ...  not spam
#
# [500 rows x 2 columns]
# Processed dataset:
#                                                   text     label
# 0     naturally irresistible your corporate identit...      spam
# 1     the stock trading gunslinger  fanny is merril...      spam
# 2     unbelievable new homes made easy  im wanting ...      spam
# 3      color printing special  request additional i...      spam
# 4     do not have money  get software cds from here...      spam
# ..                                                 ...       ...
# 495   re  invitation to speak at power   emma   it ...  not spam
# 496   re  aram  s visit  jesus   i yalked to aram  ...  not spam
# 497                         forwarded by vince j ka...  not spam
# 498   reschedule meeting for duffie report  hi shir...  not spam
# 499   re  enl  dailyupdate  txt  please respond to ...  not spam
#
# [500 rows x 2 columns]
#
# spam messages
# 0       naturally irresistible your corporate identit...
# 1       the stock trading gunslinger  fanny is merril...
# 2       unbelievable new homes made easy  im wanting ...
# 3        color printing special  request additional i...
# 4       do not have money  get software cds from here...
#                              ...
# 244     make a fortune on ebay   ebay    rated work a...
# 245     re      yr fixed home loan  no points flu  de...
# 246     all graphics software available  cheap oem ve...
# 247     please help my child  dear sir  mam   i have ...
# 248     entrust your visual identity to us  thinking ...
# Name: text, Length: 249, dtype: object
#
# ham messages
# 249     hello guys   i  m  bugging you  for your comp...
# 250     sacramento weather station  fyi              ...
# 251     from the enron india newsdesk  jan  th newscl...
# 252     re  powerisk   your invitation  angelika   th...
# 253     re  resco database and customer capture  stev...
#                              ...
# 495     re  invitation to speak at power   emma   it ...
# 496     re  aram  s visit  jesus   i yalked to aram  ...
# 497                           forwarded by vince j ka...
# 498     reschedule meeting for duffie report  hi shir...
# 499     re  enl  dailyupdate  txt  please respond to ...
# Name: text, Length: 251, dtype: object
#
# spam words count
# {'naturally': 2, 'irresistible': 2, 'your': 589, 'corporate': 16, 'identity': 17, 'lt': 12, 'is': 636, 'really': 19, 'hard': 18, 'to': 1634, 'recollect': 8, 'a': 1009, 'company': 230, 'the': 1886, 'market': 81, 'full': 44, 'of': 1334, 'suqgestions': 6, 'and': 1445, 'information': 179, 'isoverwhelminq': 2, 'but': 102, 'good': 47, 'catchy': 8, 'logo': 45, 'stylish': 3, 'statlonery': 6, 'outstanding': 16, 'website': 82, 'will': 248, 'make': 104, 'task': 8, 'much': 52, 'easier': 12, 'we': 315, 'do': 140, 'not': 271, 'promise': 17, 'that': 408, 
 'ioc': 5, 'sanjay': 4, 'jog': 4, 'centre': 37, 'yet': 20, 'receive': 11, 'proposal': 12, 'infro': 1, 'government': 62, 'maharashtra': 51, 'wants': 22, 'delhi': 6, 'convince': 2, 'power': 185, 'trading': 48, 'corporation': 14, 'central': 5, 'utility': 5, 'buy': 17, 'dabhol': 43, 'sell': 11, 'across': 9, 'country': 7, 'would': 295, 'far': 18, 'simpler': 1, 'all': 11 ...
#
# FROM THE GIVEN DATA SET WE CAN FIND THE FOLLOWING
#
# priori probability of spam mails
# 0.498
#
# priori probability of ham mails
# 0.502
#
# Enter the mail!
# hello guys   i  m  bugging you please help my child
#
# Words in the mail:['hello', 'guys', 'i', 'm', 'bugging', 'you', 'please', 'help', 'my', 'child']
#
# count of the word 'hello' in spam mails
# 24
# count of the word 'hello' in ham mails
# 28
#
# Class conditional probabilities of word:hello
# Probability(word/spam)=0.4716981132075472
# Probability(word/ham)=0.5471698113207547
#
# count of the word 'guys' in spam mails
# 0
# count of the word 'guys' in ham mails
# 9
#
# Class conditional probabilities of word:guys
# Probability(word/spam)=0.1
# Probability(word/ham)=1.0
#
# count of the word 'i' in spam mails
# 294
# count of the word 'i' in ham mails
# 978
#
# Class conditional probabilities of word:i
# Probability(word/spam)=0.2317360565593087
# Probability(word/ham)=0.7690494893951296
#
# count of the word 'm' in spam mails
# 67
# count of the word 'm' in ham mails
# 78
#
# Class conditional probabilities of word:m
# Probability(word/spam)=0.4657534246575342
# Probability(word/ham)=0.541095890410959
#
# count of the word 'bugging' in spam mails
# 0
# count of the word 'bugging' in ham mails
# 1
#
# Class conditional probabilities of word:bugging
# Probability(word/spam)=0.5
# Probability(word/ham)=1.0
#
# count of the word 'you' in spam mails
# 781
# count of the word 'you' in ham mails
# 921
#
# Class conditional probabilities of word:you
# Probability(word/spam)=0.45918966529653554
# Probability(word/ham)=0.541397533763946
#
# count of the word 'please' in spam mails
# 96
# count of the word 'please' in ham mails
# 298
#
# Class conditional probabilities of word:please
# Probability(word/spam)=0.24556962025316456
# Probability(word/ham)=0.7569620253164557
#
# count of the word 'help' in spam mails
# 52
# count of the word 'help' in ham mails
# 68
#
# Class conditional probabilities of word:help
# Probability(word/spam)=0.4380165289256198
# Probability(word/ham)=0.5702479338842975
#
# count of the word 'my' in spam mails
# 143
# count of the word 'my' in ham mails
# 188
#
# Class conditional probabilities of word:my
# Probability(word/spam)=0.43373493975903615
# Probability(word/ham)=0.5692771084337349
#
# count of the word 'child' in spam mails
# 7
# count of the word 'child' in ham mails
# 0
#
# Class conditional probabilities of word:child
# Probability(word/spam)=1.0
# Probability(word/ham)=0.125
#
# Posterior probability of this mail to be a spam is
# 0.0140861268749201
#
# Posterior probability of this mail to be a ham is
# 0.9859138731250799
#
# Hence the mail is not a spam!
